# %% [markdown]
# This file contains implementation of a data frame.

# %%
# Importing necessary libraries

import pandas as pd
import numpy as np

# %%
# Creating a dictionary

my_dict = {

    'Name':['Teja', 'Niyaz', 'Karthish', 'Hari', 'Vishnu'],
    'Dept':['DS', 'ADTA', 'BA', 'ADTA', 'CS'],
    'Age':[25, 23, 24, 26, 22]

}

# %%
print(my_dict)
# Out:
# {'Name': ['Teja', 'Niyaz', 'Karthish', 'Hari', 'Vishnu'], 'Dept': ['DS', 'ADTA', 'BA', 'ADTA', 'CS'], 'Age': [25, 23, 24, 26, 22]}

# %%
# Converting the dictionary created into a dataframe

df = pd.DataFrame(my_dict)
print(df)
# Out:
#        Name  Dept  Age
# 0      Teja    DS   25
# 1     Niyaz  ADTA   23
# 2  Karthish    BA   24
# 3      Hari  ADTA   26
# 4    Vishnu    CS   22
